# %% [markdown]
# # Rule based approach to detect Actionable items
# <br>
# <br>
#
# * I will use token matching and Parts of speech tags to match sentences to actionable item patterns
# <br>
# - I will use Spacy pos tagger and matcher<br> https://spacy.io/usage/rule-based-matching
# <br>spacy Installation guide https://spacy.io/usage

# %% [markdown]
# ## Linguistic rule writting
# <br>
#
# refer: https://towardsdatascience.com/linguistic-rule-writing-for-nlp-ml-64d9af824ee8

# %%
import pandas as pd
import spacy
from tqdm import tqdm
import re
# i am using the spacy small model
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# - Before starting lets check the pipeline component of spacy

# %%
nlp.pipeline
#only need tagger and parser
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x240011b7cc8>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x240011b8648>),
#  ('ner', <spacy.pipeline.pipes.EntityRecognizer at 0x240011b8be8>)]

# %%
#i dont need the NER, so disabling it
nlp = spacy.load("en_core_web_sm", disable=['ner'])
nlp.pipeline
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x2400aba0188>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x2400ab9c288>)]

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser']

# %% [markdown]
# ## Load the sentence data

# %%
pd.options.display.max_colwidth = 1500
sentences_df = pd.read_csv("sentence_file.csv")
sentences_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                    sentence
# 0                                                                                                                                                                                                                                                                                                                                      Here is our forecast
# 1                                                                                                                                                                                                                                                                                       Traveling to have a business meeting takes the fun out of the trip.
# 2                                                                                                                                                                                                                                                                                                         Especially if you have to prepare a presentation.
# 3                                                                                                                                                                                                                                            I would suggest holding the business plan meetings here then take a trip without any formal business meetings.
# 4                                                                                                                                                                                                                                                             I would even try and get some honest opinions on whether a trip is even desired or necessary.
# ...                                                                                                                                                                                                                                                                                                                                                     ...
# 6627370                                                                                                                                                                                                                                                                       Any review, use, distribution or disclosure by others is strictly prohibited.
# 6627371                                                                                                                             If you are not the intended recipient (or authorized to receive for the recipient), please contact the sender or reply to Enron Corp. at enron.messaging.administration@enron.com and delete all copies of the message.
# 6627372  This e-mail (and any attachments hereto) are not intended to be an offer (or an acceptance) and do not create or evidence a binding and enforceable contract between Enron Corp. (or any of its affiliates) and the intended recipient or any other party, and may not be relied on by anyone as the basis of a contract by estoppel or otherwise.
# 6627373                                                                                                                                                                                                                                                                                                                                          Thank you.
# 6627374                                                                                                                                                                                                                                                                              **********************************************************************
#
# [6627375 rows x 1 columns]

# %% [markdown]
# ### Let me pass some strings and see how it works

# %%
example = "I would suggest holding the business plan meetings here then take a trip without any formal business meetings."

doc = nlp(example)
for ele in doc:
    print((ele, ele.pos_, ele.tag_, ele.dep_, ele.head))
# Out:
# (I, 'PRON', 'PRP', 'nsubj', suggest)
# (would, 'VERB', 'MD', 'aux', suggest)
# (suggest, 'VERB', 'VB', 'ROOT', suggest)
# (holding, 'VERB', 'VBG', 'xcomp', suggest)
# (the, 'DET', 'DT', 'det', meetings)
# (business, 'NOUN', 'NN', 'compound', plan)
# (plan, 'NOUN', 'NN', 'compound', meetings)
# (meetings, 'NOUN', 'NNS', 'dobj', holding)
# (here, 'ADV', 'RB', 'advmod', holding)
# (then, 'ADV', 'RB', 'advmod', holding)
# (take, 'VERB', 'VB', 'dep', holding)
# (a, 'DET', 'DT', 'det', trip)
# (trip, 'NOUN', 'NN', 'dobj', take)
# (without, 'ADP', 'IN', 'prep', take)
# (any, 'DET', 'DT', 'det', meetings)
# (formal, 'ADJ', 'JJ', 'amod', meetings)
# (business, 'NOUN', 'NN', 'compound', meetings)
# (meetings, 'NOUN', 'NNS', 'pobj', without)
# (., 'PUNCT', '.', 'punct', suggest)

# %%
doc[0].tag_
# Out:
# 'PRP'

# %% [markdown]
# > The number of sentences is large it will take much time to classify.
# limiting the number of sentences

# %%
NUMBER_OF_SENTENCES= 50000

def gen_tags(sent_df):
    tags_lst = []
    doc_lst = []
    for ele1 in tqdm(sent_df):
        doc = nlp(ele1)
        doc_lst.append(doc)
        tags = []
        for ele2 in doc:
            tags.append(ele2.tag_)
        tags_lst.append(tags)
    return doc_lst,tags_lst
        
        
lst_doc, lst_tags = gen_tags(sentences_df['sentence'][0:NUMBER_OF_SENTENCES])

# %%
lst_tags
# Out:
# [['RB', 'VBZ', 'PRP$', 'NN'],
#  ['VBG',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['RB', 'IN', 'PRP', 'VBP', 'TO', 'VB', 'DT', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'VBG',
#   'DT',
#   'NN',
#   'NN',
#   'NNS',
#   'RB',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'NNS',
#   '.'],
#  ['PRP',
#   'MD',
#   'RB',
#   'VB',
#   'CC',
#   'VB',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'RB',
#   'VBN',
#   'CC',
#   'JJ',
#   '.'],
#  ['RB',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'NNS',
#   ',',
#   'PRP',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'RBR',
#   'JJ',
#   'TO',
#   'VB',
#   'CC',
#   'VB',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'WP',
#   'VBZ',
#   'VBG',
#   'CC',
#   'WP',
#   'VBZ',
#   'RB',
#   '.'],
#  ['RB',
#   'RB',
#   'DT',
#   'NN',
#   'VBZ',
#   'CC',
#   'DT',
#   'NNS',
#   'VBP',
#   'JJ',
#   'RB',
#   'VBG',
#   'IN',
#   'PRP$',
#   'NN',
#   '.'],
#  ['DT',
#   'NNS',
#   'MD',
#   'VB',
#   'JJR',
#   'IN',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['PRP$', 'NN', 'IN', 'WRB', 'TO', 'VB', 'VBZ', 'NNP', '.'],
#  ['VB', 'NN', 'CC', 'VB', 'DT', 'NN', 'NN', 'CC', 'NN', 'NNP', 'POS', '.'],
#  ['VBG', 'RB', 'VBZ', 'RB', 'JJ', 'NN', '.'],
#  ['NNP', 'JJ', '.'],
#  ['NN', 'TO', 'VB', '.', '.'],
#  ['.'],
#  ['NNP',
#   ',',
#   '_SP',
#   'MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   'NN',
#   '.'],
#  ['CC',
#   'PRP$',
#   'NNS',
#   'IN',
#   'DT',
#   'NNS',
#   'WDT',
#   'VBP',
#   'TO',
#   'VB',
#   'VBN',
#   '.'],
#  ['-LRB-', 'NNP', 'NNP', 'IN', 'NN', '-RRB-', 'NNP'],
#  ['VB', 'PRP', 'VB', 'IN', 'NNP', 'IN', 'CD', '.'],
#  ['NNP', ',', '_SP', 'WRB', 'IN', 'CC', 'JJ', 'NNP', 'CC', 'NNP', '.'],
#  ['NNP'],
#  ['UH',
#   'NN',
#   'DT',
#   'VBG',
#   'NN',
#   'NN',
#   'IN',
#   'NNS',
#   ':',
#   'NNP',
#   'NNP',
#   '-LRB-',
#   'ADD',
#   '-RRB-',
#   'NNP',
#   'NNP',
#   '-LRB-',
#   'ADD',
#   '-RRB-',
#   'NNP',
#   'NNP',
#   '-LRB-',
#   'ADD',
#   '-RRB-',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'VBP',
#   'PRP',
#   'IN',
#   'PRP$',
#   'NN',
#   'NNP',
#   'NNP'],
#  ['DT', 'NN', 'IN', 'CD', 'CC', 'CD'],
#  ['LS',
#   '.',
#   'NNP',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   ':',
#   '.',
#   '_SP',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'VBP',
#   'VBN',
#   'IN',
#   'DT',
#   'NNP',
#   '_SP',
#   'CD',
#   '.',
#   '_SP',
#   'JJ',
#   'NNP',
#   'NN',
#   '_SP',
#   'NNP',
#   ':',
#   'CD',
#   '_SP',
#   'NNP',
#   ':',
#   'CD',
#   '_SP',
#   'NN',
#   ':',
#   'CD',
#   '_SP',
#   'NNP',
#   ':',
#   'CD',
#   '_SP',
#   'CD',
#   '.'],
#  ['NN', ':', 'CD', '_SP', 'NN', ':', '_SP', 'CD'],
#  ['NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   '``',
#   'NNP',
#   ',',
#   'NNP',
#   "''",
#   'XX',
#   'ADD',
#   'XX',
#   'IN',
#   'CD',
#   'CD',
#   'NN',
#   'TO',
#   ':',
#   '``',
#   '``',
#   'NNP',
#   "''",
#   "''",
#   'XX',
#   'NNP',
#   'NNP',
#   'NN',
#   ':',
#   '_SP',
#   'NN',
#   ':',
#   'NNP',
#   ':',
#   'VBN',
#   'RB',
#   'CC',
#   'JJ',
#   'NNP',
#   'NN',
#   'NN',
#   'NN',
#   'NNS',
#   '_SP',
#   'NNP',
#   ',',
#   'XX',
#   'IN',
#   'VBN',
#   '_SP',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   ',',
#   'IN',
#   'DT',
#   'NNP',
#   'CD',
#   'NN',
#   'XX',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   'NN',
#   ',',
#   'PRP',
#   'VBP',
#   'VBG',
#   'DT',
#   'XX',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'VBN',
#   'CC',
#   'NN',
#   'SYM',
#   'NN',
#   'NN',
#   '.'],
#  ['TO',
#   'VB',
#   'XX',
#   'RB',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'JJ',
#   '.'],
#  ['NNP',
#   'VBZ',
#   'DT',
#   'XX',
#   'JJ',
#   'NN',
#   'NN',
#   'VBN',
#   'IN',
#   'NNP',
#   'TO',
#   'VB',
#   'NN',
#   'XX',
#   'IN',
#   'NN',
#   'NN',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   '.'],
#  ['VBG', 'JJ', 'NN', '.'],
#  ['IN',
#   'VBG',
#   'RB',
#   ',',
#   '_SP',
#   'PRP',
#   'VBP',
#   'PRP$',
#   'XX',
#   'RBS',
#   'VBN',
#   'NN',
#   'RB',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'CD',
#   ',',
#   'CD',
#   ',',
#   'CD',
#   ',',
#   'CD',
#   'CC',
#   'CD',
#   'NNS',
#   'IN',
#   'NNP',
#   'JJ',
#   'SYM',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   'TO',
#   'VB',
#   'VBN',
#   'NNS',
#   'IN',
#   'NNP',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'NNP',
#   'POS',
#   'VBG',
#   'XX',
#   'NN',
#   'CC',
#   'VB',
#   'PRP',
#   'NNS',
#   'PRP',
#   '.'],
#  ['NNP',
#   'NN',
#   'MD',
#   'VB',
#   'NN',
#   'XX',
#   'DT',
#   'NN',
#   'JJ',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   '.'],
#  ['RB', 'VBZ', 'NNP', 'NN', 'XX', 'NN', 'NN', ',', 'RB', 'PRP', '.'],
#  ['XX',
#   'XX',
#   'PRP',
#   'VBP',
#   'VBG',
#   'VBG',
#   'CD',
#   'SYM',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'NNS',
#   '-LRB-',
#   'CD',
#   'SYM',
#   'CD',
#   '-RRB-',
#   'IN',
#   'NNP',
#   'NNP',
#   '.'],
#  ['XX',
#   'NN',
#   'NN',
#   'VBZ',
#   'IN',
#   'IN',
#   'NN',
#   'NNS',
#   'VBP',
#   'IN',
#   'JJ',
#   'NN',
#   '.'],
#  ['XX',
#   'XX',
#   'IN',
#   'CD',
#   'SYM',
#   'CD',
#   'NNS',
#   'DT',
#   'NN',
#   '_SP',
#   'JJ',
#   'NN',
#   'NN',
#   ':',
#   'XX',
#   'NN',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'CD',
#   'SYM',
#   'CD',
#   'NNP',
#   'IN',
#   'NN',
#   'XX',
#   'NNP',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'CD',
#   'SYM',
#   'CD',
#   'NNP',
#   'IN',
#   'NN',
#   'XX',
#   'XX',
#   'NN',
#   'MD',
#   'RB',
#   'VB',
#   'VBN',
#   'IN',
#   'NNP',
#   'IN',
#   'NNP',
#   ',',
#   'IN',
#   'NN',
#   'XX',
#   'JJ',
#   'NN',
#   '.'],
#  ['XX',
#   'NN',
#   'NN',
#   'VBD',
#   ':',
#   'NN',
#   'NN',
#   'RB',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'NNP',
#   'NNP',
#   'NNP',
#   'CC',
#   'NNP',
#   'XX',
#   'VBP',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'NN',
#   'NN',
#   '-LRB-',
#   'NN',
#   'CC',
#   'XX',
#   'JJ',
#   '-RRB-',
#   '.'],
#  ['XX',
#   'XX',
#   'MD',
#   'PRP',
#   'VB',
#   'JJ',
#   'NNS',
#   ',',
#   'VB',
#   'PRP',
#   'DT',
#   'NN',
#   '.'],
#  ['XX', 'VB', 'PRP', 'VB', 'PRP', ',', 'DT', 'VBZ', 'JJ', 'NN', '.', '.'],
#  ['XX',
#   'XX',
#   'NNP',
#   'NNP',
#   ',',
#   'NNP',
#   ',',
#   'NNP',
#   'XX',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'CC',
#   'NNP',
#   'XX',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'XX',
#   'NNP',
#   'NNP',
#   'NNP',
#   ',',
#   'NNP',
#   'XX',
#   'CD',
#   'NNP',
#   'NNP',
#   'NNP',
#   'XX',
#   'NNP',
#   ',',
#   'NNP',
#   'CD',
#   'XX',
#   'CD',
#   'HYPH',
#   'CD',
#   'HYPH',
#   'CD',
#   'XX',
#   'CD',
#   'HYPH',
#   'CD',
#   'HYPH',
#   'CD',
#   'XX',
#   'CD',
#   'HYPH',
#   'CD',
#   'HYPH',
#   'CD',
#   'XX',
#   'NNP',
#   'HYPH',
#   'CD',
#   'XX'],
#  ['NNP',
#   'NNP',
#   ',',
#   '_SP',
#   'IN',
#   'VBN',
#   'NN',
#   'IN',
#   'NNP',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'NNPS',
#   'VBZ',
#   'DT',
#   'JJ',
#   '_SP',
#   'NNP',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'VBN', 'PRP$', 'NN', 'IN', 'NNP', 'NNP', 'IN', 'NNP', '.'],
#  ['PRP$', 'NN', '_SP', 'NN', 'VBZ', 'CD', 'HYPH', 'CD', 'HYPH', 'CD', '.'],
#  ['NNP', 'NNP'],
#  ['NNP',
#   ',',
#   '_SP',
#   'RB',
#   'VBP',
#   'DT',
#   'NNS',
#   ':',
#   '_SP',
#   'VB',
#   'PRP',
#   'CC',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['VB', 'DT', 'NNS', 'IN', 'PRP', 'VBP', 'RB', '_SP', 'VB', 'DT', 'NNS', '.'],
#  ['LS', '.'],
#  ['VB', 'IN', 'NNP', 'IN', '_SP', 'CD', '.'],
#  ['VB',
#   'IN',
#   'DT',
#   'NN',
#   'RP',
#   'NN',
#   'IN',
#   'NNP',
#   'IN',
#   ':',
#   '_SP',
#   'CD',
#   '.'],
#  ['VB',
#   'IN',
#   'DT',
#   '_SP',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   ':',
#   'VB',
#   '_SP',
#   'CD',
#   '.'],
#  ['VB', 'IN', 'DT', 'JJ', 'NN', '_SP', 'CD', '.'],
#  ['VB', 'IN', 'NNP', ':', 'NNP'],
#  ['NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'CD',
#   'CD',
#   'NN',
#   'TO',
#   ':',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   '_SP',
#   'NN',
#   ':',
#   'JJ',
#   'NNS',
#   ':',
#   'NNS',
#   'CC',
#   'TO',
#   'VB',
#   'NN',
#   'NNP',
#   ',',
#   '_SP',
#   'RB',
#   'VBZ',
#   'DT',
#   'NNS',
#   'CC',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'IN',
#   'VBG',
#   'DT',
#   '_SP',
#   'NNS',
#   'IN',
#   'JJ',
#   'JJ',
#   'SYM',
#   'JJ',
#   'NNS',
#   'CC',
#   'NN',
#   '_SP',
#   'NN',
#   'NN',
#   '.'],
#  ['WP',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'POS',
#   'NN',
#   ':',
#   '_SP',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   '.'],
#  ['IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   '_SP',
#   'IN',
#   'NNP',
#   ',',
#   '_SP',
#   'VBD',
#   'JJ',
#   'DT',
#   'NN',
#   'IN',
#   'VBG',
#   'DT',
#   'RB',
#   'JJ',
#   '_SP',
#   'JJ',
#   'NN',
#   'NN',
#   ',',
#   'MD',
#   'VB',
#   'RB',
#   'JJ',
#   'CC',
#   'NN',
#   '_SP',
#   'VBG',
#   '.'],
#  ['IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'NNP',
#   'VBD',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'JJ',
#   'NN',
#   ',',
#   'CC',
#   'DT',
#   'NN',
#   'VBD',
#   'TO',
#   'VB',
#   'PRP',
#   'IN',
#   'IN',
#   'DT',
#   'NN',
#   'MD',
#   '_SP',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   '-LRB-',
#   'RB',
#   'IN',
#   'NNP',
#   '-RRB-',
#   '.'],
#  ['WP',
#   'VBZ',
#   'TO',
#   '_SP',
#   'VB',
#   'IN',
#   'NNP',
#   'IN',
#   'CD',
#   'SYM',
#   'CD',
#   'VBZ',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'VBN',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'JJ',
#   'NN',
#   'NN',
#   ',',
#   'DT',
#   'VBZ',
#   'JJ',
#   '.'],
#  ['DT',
#   'VBZ',
#   'RB',
#   'VB',
#   '_SP',
#   'VBG',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'RBR',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   ',',
#   'CC',
#   'IN',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'WDT',
#   'MD',
#   'VB',
#   'VBN',
#   'PRP',
#   'VBP',
#   'JJ',
#   '_SP',
#   'NNS',
#   '.'],
#  ['RB',
#   ',',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   '_SP',
#   'NN',
#   'IN',
#   'JJ',
#   'JJ',
#   'SYM',
#   'JJ',
#   'NNS',
#   'CC',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['DT',
#   'JJ',
#   'NNS',
#   'WDT',
#   'VBP',
#   'VBN',
#   'VBN',
#   'MD',
#   'VB',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'IN',
#   '_SP',
#   'PRP',
#   ',',
#   'CC',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'VBN',
#   'IN',
#   'NNS',
#   'IN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBN',
#   'VBN',
#   'IN',
#   'JJS',
#   'IN',
#   'DT',
#   'NNS',
#   'CC',
#   'DT',
#   'NNS',
#   'VBP',
#   'VBN',
#   '_SP',
#   'JJ',
#   '.'],
#  ['PRP',
#   'VBP',
#   'EX',
#   'VBZ',
#   'VBN',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   ',',
#   'CC',
#   'RB',
#   '_SP',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   'PRP',
#   'VBP',
#   'RP',
#   'TO',
#   'VB',
#   '.'],
#  ['NNP',
#   '_SP',
#   'NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'CD',
#   'CD',
#   'NN',
#   'TO',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   '_SP',
#   'NN',
#   ':',
#   'JJ',
#   'NNS',
#   ':',
#   'NNS',
#   'CC',
#   'TO',
#   'VB',
#   'VB',
#   '_SP',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'DT',
#   'NNS',
#   'VBG',
#   'JJ',
#   '_SP',
#   'NNS',
#   ',',
#   'PRP',
#   'VBP',
#   'PRP',
#   'RB',
#   'VBP',
#   'DT',
#   'VBG',
#   'NNS',
#   ':',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['PRP',
#   'VB',
#   'VBN',
#   '_SP',
#   'CD',
#   'NNS',
#   'WDT',
#   'VBD',
#   'RP',
#   'RB',
#   'JJ',
#   'NNS',
#   'IN',
#   'JJ',
#   '_SP',
#   'NNS',
#   '.'],
#  ['PRP',
#   'RB',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'TO',
#   'VB',
#   'VB',
#   'DT',
#   'NN',
#   '_SP',
#   'NNS',
#   'CC',
#   'VB',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'VBG',
#   'DT',
#   'NNS',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   ',',
#   'JJ',
#   'IN',
#   'WDT',
#   'VBP',
#   'IN',
#   '_SP',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   '.'],
#  ['NNS',
#   'VBD',
#   'TO',
#   'VB',
#   ':',
#   'PRP',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   '_SP',
#   'VB',
#   'PRP',
#   'RB',
#   'JJ',
#   'IN',
#   'JJ',
#   'WP',
#   'PRP',
#   'VBP',
#   'VBG',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'VB', 'WDT', 'NNS', 'VBP', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'TO',
#   'VB',
#   'WDT',
#   'VBP',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   'CC',
#   'WDT',
#   'VBP',
#   'IN',
#   'IN',
#   'NN',
#   '.'],
#  ['IN',
#   'DT',
#   'IN',
#   'NN',
#   ',',
#   'VBP',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   '-LRB-',
#   'NN',
#   '-RRB-',
#   'IN',
#   'DT',
#   'CC',
#   '_SP',
#   'NN',
#   'IN',
#   'NNS',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   '.'],
#  ['VB',
#   'DT',
#   'VBN',
#   'VBD',
#   'IN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   ':',
#   'JJ',
#   'NN',
#   'CC',
#   'DT',
#   '_SP',
#   'NN',
#   'NNS',
#   '.'],
#  ['VB', 'DT', 'JJ', 'TO', 'VB', 'DT', 'NN', 'NN', '.'],
#  ['NNS',
#   'VBD',
#   'RB',
#   'RB',
#   '-LRB-',
#   'DT',
#   'JJ',
#   'NN',
#   '-RRB-',
#   ':',
#   'NN',
#   'IN',
#   'NNP',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'NN',
#   'CC',
#   'NN',
#   '_SP',
#   'NN',
#   '.'],
#  ['JJ',
#   'NNS',
#   'CC',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '-LRB-',
#   'FW',
#   'FW',
#   'VBZ',
#   'SYM',
#   'NNS',
#   'WDT',
#   '_SP',
#   'VB',
#   'RP',
#   'VBG',
#   'NN',
#   'NN',
#   'NNS',
#   'SYM',
#   'NNS',
#   '-RRB-',
#   '.'],
#  ['JJ',
#   'NN',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'RP',
#   'NNS',
#   'IN',
#   ':',
#   'JJ',
#   ',',
#   '_SP',
#   'NN',
#   ',',
#   'NNS',
#   ',',
#   'NNS',
#   ',',
#   '.'],
#  ['NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'HYPH',
#   'NN',
#   'NNS',
#   '_SP',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   'WDT',
#   'DT',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   '.'],
#  ['NN',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'NNS',
#   'TO',
#   'VB',
#   '_SP',
#   'VBN',
#   'RB',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['DT',
#   'VBD',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '_SP',
#   'MD',
#   'VB',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['NN',
#   'TO',
#   'RB',
#   'VB',
#   'NN',
#   'NN',
#   'IN',
#   'VB',
#   'HYPH',
#   'IN',
#   'HYPH',
#   'NN',
#   'NNS',
#   ':',
#   'VB',
#   'DT',
#   '_SP',
#   'JJ',
#   'NNS',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   ':',
#   'NNP',
#   'NNP',
#   'IN',
#   'JJ',
#   'NN',
#   ',',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'NNP',
#   ',',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'NN',
#   '.'],
#  ['NN',
#   'IN',
#   'NNP',
#   'TO',
#   'VB',
#   'NN',
#   'NNS',
#   'VBN',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'RB',
#   'IN',
#   '_SP',
#   'VBG',
#   'JJ',
#   'NNS',
#   '.'],
#  ['NNP', 'CC', 'NNP', 'NN', 'IN', 'DT', 'NN', 'NNS', '.'],
#  ['NN',
#   'TO',
#   'VB',
#   'DT',
#   'NNP',
#   'NNP',
#   'NN',
#   'IN',
#   'NNP',
#   ':',
#   'NN',
#   'IN',
#   'NN',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NNS',
#   '.'],
#  ['NN', 'TO', 'VB', 'NN', '_SP', 'NN', 'CC', 'NNS', '.'],
#  ['NN', 'TO', 'VB', 'DT', 'NNS', 'RB', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['JJ',
#   'NN',
#   'VBZ',
#   'IN',
#   'NNS',
#   'VBG',
#   'JJ',
#   'NN',
#   'CC',
#   'DT',
#   '_SP',
#   'NN',
#   'NN',
#   '.'],
#  ['NN', 'IN', 'NNP', 'NNP', 'NNS', '.'],
#  ['DT',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'NNS',
#   '-LRB-',
#   'NNS',
#   'XX',
#   'NN',
#   'SYM',
#   'NNP',
#   '-RRB-',
#   '.'],
#  ['NNP', '.'],
#  ['NN', 'IN', 'NNS', 'IN', 'JJ', 'NNS', 'RB', 'VBN', 'IN', 'NNS', '.'],
#  ['NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'IN',
#   'VBN',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '_SP',
#   'NN',
#   '.'],
#  ['NN', 'TO', 'VB', 'NN', 'NN', 'NNP', 'IN', 'DT', 'NNP', 'NN', 'NN', '.'],
#  ['VB',
#   'JJ',
#   'NN',
#   'NNS',
#   ',',
#   '_SP',
#   'JJ',
#   'NN',
#   'NNS',
#   ',',
#   'CC',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['VB',
#   'NN',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'NN',
#   '.'],
#  ['NN',
#   'NN',
#   'RP',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   '_SP',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['JJ', 'NNS', 'IN', 'NNP', '.'],
#  ['NN', 'IN', 'NNP', 'IN', 'NNP', '.'],
#  ['NN', 'CC', 'NN', 'NNP', 'NNS', '.'],
#  ['JJ', '_SP', 'CC', 'JJ', 'NN', 'VBP', 'RP', 'NNS', '.'],
#  [':', 'NNP', '.'],
#  ['NNP',
#   ':',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'RP',
#   'DT',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   '_SP',
#   'NN',
#   '.'],
#  ['RB',
#   'PRP',
#   'MD',
#   'VB',
#   'RB',
#   'JJR',
#   'WRB',
#   'DT',
#   'NN',
#   'VBZ',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   '.'],
#  ['NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'CD',
#   'CD',
#   'NN',
#   'TO',
#   ':',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   '_SP',
#   'NN',
#   ':',
#   'JJ',
#   'NNS',
#   ':',
#   'NNS',
#   'CC',
#   'TO',
#   'VB',
#   'NN',
#   'NNP',
#   ',',
#   '_SP',
#   'RB',
#   'VBZ',
#   'DT',
#   'NNS',
#   'CC',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'IN',
#   'VBG',
#   'DT',
#   '_SP',
#   'NNS',
#   'IN',
#   'JJ',
#   'JJ',
#   'SYM',
#   'JJ',
#   'NNS',
#   'CC',
#   'NN',
#   '_SP',
#   'NN',
#   'NN',
#   '.'],
#  ['WP',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'POS',
#   'NN',
#   ':',
#   '_SP',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   '.'],
#  ['IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   '_SP',
#   'IN',
#   'NNP',
#   ',',
#   '_SP',
#   'VBD',
#   'JJ',
#   'DT',
#   'NN',
#   'IN',
#   'VBG',
#   'DT',
#   'RB',
#   'JJ',
#   '_SP',
#   'JJ',
#   'NN',
#   'NN',
#   ',',
#   'MD',
#   'VB',
#   'RB',
#   'JJ',
#   'CC',
#   'NN',
#   '_SP',
#   'VBG',
#   '.'],
#  ['IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'NNP',
#   'VBD',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'JJ',
#   'NN',
#   ',',
#   'CC',
#   'DT',
#   'NN',
#   'VBD',
#   'TO',
#   'VB',
#   'PRP',
#   'IN',
#   'IN',
#   'DT',
#   'NN',
#   'MD',
#   '_SP',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   '-LRB-',
#   'RB',
#   'IN',
#   'NNP',
#   '-RRB-',
#   '.'],
#  ['WP',
#   'VBZ',
#   'TO',
#   '_SP',
#   'VB',
#   'IN',
#   'NNP',
#   'IN',
#   'CD',
#   'SYM',
#   'CD',
#   'VBZ',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'VBN',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'JJ',
#   'NN',
#   'NN',
#   ',',
#   'DT',
#   'VBZ',
#   'JJ',
#   '.'],
#  ['DT',
#   'VBZ',
#   'RB',
#   'VB',
#   '_SP',
#   'VBG',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'RBR',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   ',',
#   'CC',
#   'IN',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'WDT',
#   'MD',
#   'VB',
#   'VBN',
#   'PRP',
#   'VBP',
#   'JJ',
#   '_SP',
#   'NNS',
#   '.'],
#  ['RB',
#   ',',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   '_SP',
#   'NN',
#   'IN',
#   'JJ',
#   'JJ',
#   'SYM',
#   'JJ',
#   'NNS',
#   'CC',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['DT',
#   'JJ',
#   'NNS',
#   'WDT',
#   'VBP',
#   'VBN',
#   'VBN',
#   'MD',
#   'VB',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'IN',
#   '_SP',
#   'PRP',
#   ',',
#   'CC',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'VBN',
#   'IN',
#   'NNS',
#   'IN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBN',
#   'VBN',
#   'IN',
#   'JJS',
#   'IN',
#   'DT',
#   'NNS',
#   'CC',
#   'DT',
#   'NNS',
#   'VBP',
#   'VBN',
#   '_SP',
#   'JJ',
#   '.'],
#  ['PRP',
#   'VBP',
#   'EX',
#   'VBZ',
#   'VBN',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   ',',
#   'CC',
#   'RB',
#   '_SP',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   'PRP',
#   'VBP',
#   'RP',
#   'TO',
#   'VB',
#   '.'],
#  ['NNP',
#   '_SP',
#   'NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'CD',
#   'CD',
#   'NN',
#   'TO',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   '_SP',
#   'NN',
#   ':',
#   'JJ',
#   'NNS',
#   ':',
#   'NNS',
#   'CC',
#   'TO',
#   'VB',
#   'VB',
#   '_SP',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'DT',
#   'NNS',
#   'VBG',
#   'JJ',
#   '_SP',
#   'NNS',
#   ',',
#   'PRP',
#   'VBP',
#   'PRP',
#   'RB',
#   'VBP',
#   'DT',
#   'VBG',
#   'NNS',
#   ':',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['PRP',
#   'VB',
#   'VBN',
#   '_SP',
#   'CD',
#   'NNS',
#   'WDT',
#   'VBD',
#   'RP',
#   'RB',
#   'JJ',
#   'NNS',
#   'IN',
#   'JJ',
#   '_SP',
#   'NNS',
#   '.'],
#  ['PRP',
#   'RB',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'TO',
#   'VB',
#   'VB',
#   'DT',
#   'NN',
#   '_SP',
#   'NNS',
#   'CC',
#   'VB',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'VBG',
#   'DT',
#   'NNS',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   ',',
#   'JJ',
#   'IN',
#   'WDT',
#   'VBP',
#   'IN',
#   '_SP',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   '.'],
#  ['NNS',
#   'VBD',
#   'TO',
#   'VB',
#   ':',
#   'PRP',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   '_SP',
#   'VB',
#   'PRP',
#   'RB',
#   'JJ',
#   'IN',
#   'JJ',
#   'WP',
#   'PRP',
#   'VBP',
#   'VBG',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'VB', 'WDT', 'NNS', 'VBP', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'TO',
#   'VB',
#   'WDT',
#   'VBP',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   'CC',
#   'WDT',
#   'VBP',
#   'IN',
#   'IN',
#   'NN',
#   '.'],
#  ['IN',
#   'DT',
#   'IN',
#   'NN',
#   ',',
#   'VBP',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   '-LRB-',
#   'NN',
#   '-RRB-',
#   'IN',
#   'DT',
#   'CC',
#   '_SP',
#   'NN',
#   'IN',
#   'NNS',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   '.'],
#  ['VB',
#   'DT',
#   'VBN',
#   'VBD',
#   'IN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   ':',
#   'JJ',
#   'NN',
#   'CC',
#   'DT',
#   '_SP',
#   'NN',
#   'NNS',
#   '.'],
#  ['VB', 'DT', 'JJ', 'TO', 'VB', 'DT', 'NN', 'NN', '.'],
#  ['NNS',
#   'VBD',
#   'RB',
#   'RB',
#   '-LRB-',
#   'DT',
#   'JJ',
#   'NN',
#   '-RRB-',
#   ':',
#   'NN',
#   'IN',
#   'NNP',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'NN',
#   'CC',
#   'NN',
#   '_SP',
#   'NN',
#   '.'],
#  ['JJ',
#   'NNS',
#   'CC',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '-LRB-',
#   'FW',
#   'FW',
#   'VBZ',
#   'SYM',
#   'NNS',
#   'WDT',
#   '_SP',
#   'VB',
#   'RP',
#   'VBG',
#   'NN',
#   'NN',
#   'NNS',
#   'SYM',
#   'NNS',
#   '-RRB-',
#   '.'],
#  ['JJ',
#   'NN',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'RP',
#   'NNS',
#   'IN',
#   ':',
#   'JJ',
#   ',',
#   '_SP',
#   'NN',
#   ',',
#   'NNS',
#   ',',
#   'NNS',
#   ',',
#   '.'],
#  ['NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'HYPH',
#   'NN',
#   'NNS',
#   '_SP',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   'WDT',
#   'DT',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   '.'],
#  ['NN',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'NNS',
#   'TO',
#   'VB',
#   '_SP',
#   'VBN',
#   'RB',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['DT',
#   'VBD',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '_SP',
#   'MD',
#   'VB',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['NN',
#   'TO',
#   'RB',
#   'VB',
#   'NN',
#   'NN',
#   'IN',
#   'VB',
#   'HYPH',
#   'IN',
#   'HYPH',
#   'NN',
#   'NNS',
#   ':',
#   'VB',
#   'DT',
#   '_SP',
#   'JJ',
#   'NNS',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   ':',
#   'NNP',
#   'NNP',
#   'IN',
#   'JJ',
#   'NN',
#   ',',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'NNP',
#   ',',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'NN',
#   '.'],
#  ['NN',
#   'IN',
#   'NNP',
#   'TO',
#   'VB',
#   'NN',
#   'NNS',
#   'VBN',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'RB',
#   'IN',
#   '_SP',
#   'VBG',
#   'JJ',
#   'NNS',
#   '.'],
#  ['NNP', 'CC', 'NNP', 'NN', 'IN', 'DT', 'NN', 'NNS', '.'],
#  ['NN',
#   'TO',
#   'VB',
#   'DT',
#   'NNP',
#   'NNP',
#   'NN',
#   'IN',
#   'NNP',
#   ':',
#   'NN',
#   'IN',
#   'NN',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NNS',
#   '.'],
#  ['NN', 'TO', 'VB', 'NN', '_SP', 'NN', 'CC', 'NNS', '.'],
#  ['NN', 'TO', 'VB', 'DT', 'NNS', 'RB', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['JJ',
#   'NN',
#   'VBZ',
#   'IN',
#   'NNS',
#   'VBG',
#   'JJ',
#   'NN',
#   'CC',
#   'DT',
#   '_SP',
#   'NN',
#   'NN',
#   '.'],
#  ['NN', 'IN', 'NNP', 'NNP', 'NNS', '.'],
#  ['DT',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'NNS',
#   '-LRB-',
#   'NNS',
#   'XX',
#   'NN',
#   'SYM',
#   'NNP',
#   '-RRB-',
#   '.'],
#  ['NNP', '.'],
#  ['NN', 'IN', 'NNS', 'IN', 'JJ', 'NNS', 'RB', 'VBN', 'IN', 'NNS', '.'],
#  ['NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'IN',
#   'VBN',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '_SP',
#   'NN',
#   '.'],
#  ['NN', 'TO', 'VB', 'NN', 'NN', 'NNP', 'IN', 'DT', 'NNP', 'NN', 'NN', '.'],
#  ['VB',
#   'JJ',
#   'NN',
#   'NNS',
#   ',',
#   '_SP',
#   'JJ',
#   'NN',
#   'NNS',
#   ',',
#   'CC',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['VB',
#   'NN',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'NN',
#   '.'],
#  ['NN',
#   'NN',
#   'RP',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   '_SP',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['JJ', 'NNS', 'IN', 'NNP', '.'],
#  ['NN', 'IN', 'NNP', 'IN', 'NNP', '.'],
#  ['NN', 'CC', 'NN', 'NNP', 'NNS', '.'],
#  ['JJ', '_SP', 'CC', 'JJ', 'NN', 'VBP', 'RP', 'NNS', '.'],
#  [':', 'NNP', '.'],
#  ['NNP',
#   ':',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'RP',
#   'DT',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   '_SP',
#   'NN',
#   '.'],
#  ['RB',
#   'PRP',
#   'MD',
#   'VB',
#   'RB',
#   'JJR',
#   'WRB',
#   'DT',
#   'NN',
#   'VBZ',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   '.'],
#  ['NNP',
#   ',',
#   '_SP',
#   'RB',
#   'VBP',
#   'DT',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'NNS',
#   'IN',
#   'NN',
#   '.'],
#  ['DT', 'NN', '_SP', 'NN', 'VBZ', 'RB', 'JJ', '.'],
#  ['NNP'],
#  ['NNP', ',', '_SP', 'CD', 'CD', 'VBZ', 'JJ', 'NNP'],
#  ['NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   'NFP',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'IN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'CD',
#   'CD',
#   'NN',
#   '_SP',
#   'IN',
#   ':',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'JJ',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'VB',
#   '_SP',
#   'NN',
#   ':',
#   'NNP',
#   ',',
#   'NN',
#   'CC',
#   'NNPS',
#   'NNP',
#   'UH',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'IN',
#   '_SP',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   ':',
#   '_SP',
#   'NNP',
#   ',',
#   'NNP',
#   'CC',
#   'NNPS',
#   'NNP',
#   '_SP',
#   'NNP',
#   ':',
#   '_SP',
#   'NNP',
#   ',',
#   'NNP',
#   'NN',
#   '_SP',
#   'NN',
#   ':',
#   '_SP',
#   'CD',
#   'SYM',
#   'CD',
#   '_SP',
#   'NN',
#   ':',
#   'NNP',
#   '_SP',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NNS',
#   'SYM',
#   'NNS',
#   ',',
#   'UH',
#   'VB',
#   'JJ',
#   'TO',
#   'VB',
#   'PRP',
#   '.'],
#  ['UH', ',', 'NN', 'NNP'],
#  ['NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'NNS',
#   'IN',
#   'VBG',
#   'DT',
#   'NNP',
#   'NN',
#   'NN',
#   '.'],
#  ['MD', 'PRP', 'UH', 'VB', 'JJ', 'PRP', 'VBZ', 'DT', 'JJ', 'NN', '.'],
#  ['VBP', 'PRP', ',', 'NNP'],
#  ['NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   '``',
#   'NNP',
#   'NNP',
#   "''",
#   'XX',
#   'NNP',
#   'XX',
#   'IN',
#   'CD',
#   'CD',
#   'NN',
#   'UH',
#   'VB',
#   'IN',
#   'XX',
#   'NNP',
#   'XX',
#   'TO',
#   ':',
#   '``',
#   'NNP',
#   'NNP',
#   "''",
#   'XX',
#   'NNP',
#   'XX',
#   'NNP',
#   ':',
#   '``',
#   'NNP',
#   'NNP',
#   "''",
#   'XX',
#   'NNP',
#   'XX',
#   '_SP',
#   'NN',
#   ':',
#   'NNP',
#   '_SP',
#   'NNP',
#   'NNP',
#   'VBP',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'IN',
#   'NNP',
#   'POS',
#   'NNP',
#   '.'],
#  ['NNP',
#   'POS',
#   'NNP',
#   'VBZ',
#   'IN',
#   'DT',
#   'NNS',
#   'VBP',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'NNP',
#   'WDT',
#   'PRP',
#   'VBD',
#   'RBR',
#   '.'],
#  ['IN',
#   'EX',
#   'VBP',
#   'DT',
#   'JJ',
#   'NNS',
#   'CC',
#   'NN',
#   'NNS',
#   ',',
#   'VB',
#   'PRP',
#   'VB',
#   '.'],
#  ['RB',
#   ',',
#   'VB',
#   'PRP',
#   'VB',
#   'PRP$',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   '.'],
#  ['NNP',
#   'NNP',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NNS',
#   'IN',
#   'NNP',
#   'NNP',
#   'VBZ',
#   'IN',
#   'NN',
#   'CC',
#   'VBN',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['DT',
#   'NN',
#   'VBZ',
#   'VBG',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   'VBZ',
#   'CD',
#   'IN',
#   'RB',
#   'CD',
#   'VBG',
#   'VBN',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   ',',
#   'WDT',
#   'RB',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['JJ',
#   'JJ',
#   'NNS',
#   'PRP',
#   'VBP',
#   'VBN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NNS',
#   'CC',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   'VBP',
#   'VBG',
#   'TO',
#   'VB',
#   'RB',
#   'JJR',
#   ',',
#   'RB',
#   '$',
#   'CD',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   'CC',
#   '$',
#   'CD',
#   'NN',
#   'IN',
#   'VBN',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   ',',
#   'CC',
#   'IN',
#   'JJ',
#   'NN',
#   '.'],
#  ['DT',
#   'NN',
#   'MD',
#   'VB',
#   'DT',
#   'JJS',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   ',',
#   'RB',
#   'IN',
#   'DT',
#   'NNS',
#   'VBP',
#   'RB',
#   '.'],
#  ['IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   ',',
#   'UH',
#   'VB',
#   'PRP',
#   'VB',
#   'IN',
#   'EX',
#   'VBZ',
#   'DT',
#   'RB',
#   ',',
#   'RB',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['DT',
#   'NN',
#   'NN',
#   'VBZ',
#   'RB',
#   'RB',
#   'VBN',
#   ',',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'TO',
#   'VB',
#   '$',
#   'CD',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'JJR', 'IN', 'DT', 'NN', 'RB', 'NN', '.'],
#  ['RB',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   ',',
#   'NNP',
#   'NNPS',
#   ',',
#   'NNP',
#   '_SP',
#   'HYPH',
#   'ADD'],
#  ['NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'CD',
#   'CD',
#   'NN',
#   'TO',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'CD',
#   '_SP',
#   'NN',
#   ':',
#   'NN',
#   'IN',
#   ':',
#   'NN',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'EX',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'NNP',
#   'NN',
#   'IN',
#   'CD',
#   'IN',
#   'NN',
#   'VBG',
#   '_SP',
#   'NNP',
#   'NNPS',
#   'IN',
#   'DT',
#   'NNP',
#   '.'],
#  ['UH', 'VB', 'PRP$', 'NNS', '.'],
#  ['VBP', 'PRP', '.'],
#  ['NNPS',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NN',
#   'CD',
#   'HYPH',
#   'CD',
#   'HYPH',
#   'CD'],
#  ['NNP', ',', 'UH', 'VB', 'DT', 'JJ', 'NN', 'IN', 'DT', 'NNP', 'NN', '.'],
#  ['IN',
#   'PRP',
#   'VBP',
#   'RB',
#   '_SP',
#   'VBD',
#   'PRP',
#   ',',
#   'VB',
#   'PRP',
#   'VB',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'PRP',
#   'DT',
#   '.'],
#  ['NNP'],
#  ['PRP', 'VBP', 'NNP', 'VBZ', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'VBG', 'PRP$', 'JJ', '.'],
#  ['NNP',
#   ',',
#   '_SP',
#   'UH',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP$',
#   'NNP',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'PRP$', 'NN', 'IN', 'DT', '_SP', 'JJ', 'NN', '.'],
#  ['VBP', 'PRP', 'VB', 'PRP', 'TO', 'VB', 'DT', 'IN', 'PRP', '.'],
#  ['NNP'],
#  ['NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   'IN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'CD',
#   'CD',
#   'NN',
#   '_SP',
#   'NNP',
#   ',',
#   '_SP',
#   'IN',
#   'PRP',
#   'VBD',
#   'NN',
#   ',',
#   'PRP',
#   'VBP',
#   'JJ',
#   'EX',
#   'MD',
#   'VB',
#   'VBN',
#   'DT',
#   'NN',
#   'TO',
#   '_SP',
#   'VB',
#   'DT',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBZ',
#   'IN',
#   'DT',
#   'JJ',
#   '_SP',
#   'NN',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'CD',
#   'CC',
#   'CD',
#   'CC',
#   'VBN',
#   'IN',
#   '_SP',
#   'NN',
#   'NNS',
#   '-LRB-',
#   '$',
#   'CD',
#   '-RRB-',
#   'IN',
#   'NNP',
#   'NNP',
#   'NN',
#   '.'],
#  ['IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   ',',
#   '_SP',
#   'NNS',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'RB',
#   '-LRB-',
#   'CD',
#   'TO',
#   'CD',
#   'NNS',
#   '-RRB-',
#   'JJR',
#   'NNS',
#   'VBD',
#   '_SP',
#   'VBN',
#   'IN',
#   'NN',
#   'TO',
#   'VB',
#   'JJR',
#   'NNS',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   '_SP',
#   'NN',
#   '.'],
#  ['RB',
#   ',',
#   'DT',
#   'NNS',
#   'VBP',
#   'IN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'VBN',
#   '_SP',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   'NNP',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'CC',
#   'JJ',
#   'NNS',
#   'VBN',
#   'IN',
#   '_SP',
#   'NNP',
#   'CD',
#   'IN',
#   'NNP',
#   'CD',
#   '.'],
#  ['DT',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   '_SP',
#   'NNP',
#   'NNP',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   ',',
#   'NNP',
#   'POS',
#   'JJ',
#   'NN',
#   'NNS',
#   ',',
#   'CC',
#   'CD',
#   'NN',
#   '_SP',
#   'NNS',
#   '-LRB-',
#   'NNP',
#   ',',
#   'NNP',
#   ',',
#   'CC',
#   'NNP',
#   '-RRB-',
#   '.'],
#  ['UH',
#   'VB',
#   'DT',
#   'VBN',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VBN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '_SP',
#   'JJ',
#   'NNS',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'NNP',
#   'VBN',
#   'IN',
#   'JJ',
#   'NN',
#   '_SP',
#   'NNS',
#   '.'],
#  ['DT',
#   'CD',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NNS',
#   'VBP',
#   'IN',
#   'VBZ',
#   ':',
#   '_SP',
#   'CD',
#   '.'],
#  ['DT',
#   'JJ',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   '-LRB-',
#   'CD',
#   '-RRB-',
#   'VBP',
#   'RB',
#   'JJR',
#   '_SP',
#   'IN',
#   'DT',
#   'JJ',
#   'JJ',
#   'NNS',
#   '-LRB-',
#   'CD',
#   '-RRB-',
#   'IN',
#   'DT',
#   'NNS',
#   '.'],
#  ['LS', '.'],
#  ['DT',
#   'NN',
#   'NN',
#   'IN',
#   'NNP',
#   'NNP',
#   'CC',
#   'JJ',
#   'NNS',
#   '-LRB-',
#   'NNP',
#   'CC',
#   '_SP',
#   'NNP',
#   '-RRB-',
#   '_SP',
#   'VBZ',
#   '_SP',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'CC',
#   '_SP',
#   'NNP',
#   'NN',
#   'RB',
#   '.'],
#  ['PRP',
#   'VBZ',
#   'RB',
#   'VB',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'NNS',
#   'IN',
#   '_SP',
#   'VBP',
#   'RB',
#   'JJ',
#   '.'],
#  ['PRP', 'VBP', 'PRP', 'VBP', 'DT', 'NNS', 'VBN', 'IN', 'NNS', '.'],
#  ['RB',
#   ',',
#   'DT',
#   '_SP',
#   'NNS',
#   'VBN',
#   'MD',
#   'VB',
#   'NN',
#   'NNS',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'TO',
#   '_SP',
#   'VB',
#   'IN',
#   'EX',
#   'VBD',
#   'RB',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'CD',
#   'POS',
#   'CC',
#   'DT',
#   'NNS',
#   'VBP',
#   '_SP',
#   'NNS',
#   '.'],
#  ['PRP',
#   'VBD',
#   'TO',
#   'VB',
#   'PRP',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'NN',
#   'TO',
#   'NN',
#   'IN',
#   '_SP',
#   'VBG',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBZ',
#   'NNP',
#   'POS',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   '_SP',
#   '$',
#   'CD',
#   'CC',
#   'JJR',
#   '_SP',
#   'VBD',
#   'IN',
#   'NN',
#   'NNS',
#   'WDT',
#   'MD',
#   'VB',
#   'VBN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBZ',
#   'PRP$',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'CC',
#   'JJ',
#   'NNS',
#   'IN',
#   'WDT',
#   'IN',
#   '_SP',
#   'VB',
#   'PRP$',
#   'JJ',
#   'CC',
#   'JJ',
#   'NN',
#   '.'],
#  ['UH',
#   'VB',
#   'PRP',
#   '_SP',
#   'RB',
#   'PRP',
#   'MD',
#   'VB',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['RB', ',', 'NNP', 'NNP'],
#  ['NNP',
#   ',',
#   '_SP',
#   'IN',
#   'PRP',
#   'VBD',
#   'NN',
#   ',',
#   'PRP',
#   'VBP',
#   'JJ',
#   'EX',
#   'VBZ',
#   'VBN',
#   'DT',
#   'NN',
#   'TO',
#   '_SP',
#   'VB',
#   'DT',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'JJ',
#   'NN',
#   '.'],
#  ['DT',
#   'JJ',
#   'NN',
#   'VBD',
#   'DT',
#   '_SP',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'CD',
#   'CC',
#   'CD',
#   'CC',
#   'VBN',
#   'IN',
#   'NN',
#   'NNS',
#   '_SP',
#   '-LRB-',
#   '$',
#   'CD',
#   '-RRB-',
#   'IN',
#   'NNP',
#   'NNP',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   '.'],
#  ['IN',
#   'DT',
#   '_SP',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   ',',
#   'VBZ',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'RB',
#   '-LRB-',
#   'CD',
#   'TO',
#   'CD',
#   '_SP',
#   'NNS',
#   '-RRB-',
#   'JJR',
#   'NNS',
#   'VBD',
#   'VBN',
#   'IN',
#   'NN',
#   'TO',
#   'VB',
#   'JJR',
#   'NNS',
#   'IN',
#   '_SP',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['RB',
#   ',',
#   'DT',
#   'NNS',
#   'VBP',
#   'IN',
#   'IN',
#   '_SP',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   'NNP',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'CC',
#   'JJ',
#   'NNS',
#   'VBN',
#   'IN',
#   '_SP',
#   'NNP',
#   'CD',
#   'IN',
#   'NNP',
#   'CD',
#   '.'],
#  ['DT',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   '_SP',
#   'NNP',
#   'NNP',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   ',',
#   'NNP',
#   'POS',
#   'JJ',
#   'NN',
#   'NNS',
#   ',',
#   'CC',
#   'CD',
#   'NN',
#   '_SP',
#   'NNS',
#   '-LRB-',
#   'NNP',
#   ',',
#   'NNP',
#   ',',
#   'CC',
#   'NNP',
#   '-RRB-',
#   '.'],
#  ['UH',
#   'VB',
#   'DT',
#   'VBN',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VBN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '_SP',
#   'JJ',
#   'NNS',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'NNP',
#   'VBN',
#   'IN',
#   'JJ',
#   'NN',
#   '_SP',
#   'NNS',
#   '.'],
#  ['DT',
#   'CD',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NNS',
#   'VBP',
#   'IN',
#   'VBZ',
#   ':',
#   '_SP',
#   'CD',
#   '.'],
#  ['DT',
#   'JJ',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   '-LRB-',
#   'CD',
#   '-RRB-',
#   'VBP',
#   'RB',
#   'JJR',
#   '_SP',
#   'IN',
#   'DT',
#   'JJ',
#   'JJ',
#   'NNS',
#   '-LRB-',
#   'CD',
#   '-RRB-',
#   'IN',
#   'DT',
#   'NNS',
#   '.'],
#  ['LS', '.'],
#  ['DT',
#   'NN',
#   'NN',
#   'IN',
#   'NNP',
#   'NNP',
#   'CC',
#   'JJ',
#   'NNS',
#   '-LRB-',
#   'NNP',
#   'CC',
#   '_SP',
#   'NNP',
#   '-RRB-',
#   '_SP',
#   'VBZ',
#   '_SP',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'CC',
#   '_SP',
#   'NNP',
#   'NN',
#   'RB',
#   '.'],
#  ['PRP',
#   'VBZ',
#   'RB',
#   'VB',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'NNS',
#   'IN',
#   '_SP',
#   'VBP',
#   'RB',
#   'JJ',
#   '.'],
#  ['PRP', 'VBP', 'PRP', 'VBP', 'DT', 'NNS', 'VBN', 'IN', 'NNS', '.'],
#  ['RB',
#   ',',
#   'DT',
#   '_SP',
#   'NNS',
#   'VBN',
#   'MD',
#   'VB',
#   'NN',
#   'NNS',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'TO',
#   '_SP',
#   'VB',
#   'IN',
#   'EX',
#   'VBD',
#   'RB',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'CD',
#   'POS',
#   'CC',
#   'DT',
#   'NNS',
#   'VBP',
#   '_SP',
#   'NNS',
#   '.'],
#  ['PRP',
#   'VBD',
#   'TO',
#   'VB',
#   'PRP',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'NN',
#   'TO',
#   'NN',
#   'IN',
#   '_SP',
#   'VBG',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBZ',
#   'NNP',
#   'POS',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   '_SP',
#   '$',
#   'CD',
#   'CC',
#   'JJR',
#   '_SP',
#   'VBD',
#   'IN',
#   'NN',
#   'NNS',
#   'WDT',
#   'MD',
#   'VB',
#   'VBN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBZ',
#   'PRP$',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'CC',
#   'JJ',
#   'NNS',
#   'IN',
#   'WDT',
#   'IN',
#   '_SP',
#   'VB',
#   'PRP$',
#   'JJ',
#   'CC',
#   'JJ',
#   'NN',
#   '.'],
#  ['UH',
#   'VB',
#   'PRP',
#   '_SP',
#   'RB',
#   'PRP',
#   'MD',
#   'VB',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['RB', ',', 'NNP', 'NNP'],
#  ['NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   '``',
#   'NNP',
#   'NNP',
#   "''",
#   'XX',
#   'NNP',
#   'XX',
#   'IN',
#   'CD',
#   'CD',
#   'NN',
#   'UH',
#   'VB',
#   'IN',
#   'XX',
#   'NNP',
#   'XX',
#   'TO',
#   ':',
#   '``',
#   'NNP',
#   'NNP',
#   "''",
#   'XX',
#   'NNP',
#   'XX',
#   'NNP',
#   ':',
#   '``',
#   'NNP',
#   'NNP',
#   "''",
#   'XX',
#   'NNP',
#   'XX',
#   ',',
#   '``',
#   'NNP',
#   'NNP',
#   'NNP',
#   "''",
#   '_SP',
#   'XX',
#   'NNP',
#   'XX',
#   '_SP',
#   'NN',
#   ':',
#   'NN',
#   'NN',
#   '_SP',
#   'NNP',
#   ':',
#   'RB',
#   'DT',
#   'NN',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   '-LRB-',
#   'CC',
#   'NNP',
#   '-RRB-',
#   'JJ',
#   'NN',
#   '.'],
#  ['DT',
#   'NNP',
#   'NNP',
#   'VBZ',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['NNP',
#   'NNP',
#   'CC',
#   'NNP',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'NNS',
#   ',',
#   'NN',
#   'NNS',
#   'NNS',
#   'CC',
#   'NN',
#   'NNS',
#   'MD',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['DT',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   'CC',
#   'DT',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   'NNP',
#   'MD',
#   'RB',
#   'RB',
#   'VB',
#   'DT',
#   'NNS',
#   '.'],
#  ['IN',
#   'DT',
#   'NNP',
#   '-RRB-',
#   'VBP',
#   'RB',
#   'VB',
#   'IN',
#   'DT',
#   'NNS',
#   ',',
#   'DT',
#   'RB',
#   'VBZ',
#   'IN',
#   'DT',
#   'JJR',
#   'NN',
#   'IN',
#   'NN',
#   'VBZ',
#   'VBN',
#   'CC',
#   'DT',
#   'NN',
#   'POS',
#   'NN',
#   'IN',
#   'NNS',
#   'VBZ',
#   'VBN',
#   '.'],
#  ['DT',
#   'NNS',
#   'IN',
#   'JJ',
#   'NN',
#   ',',
#   'WDT',
#   'VBP',
#   'VBN',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   ',',
#   'VBP',
#   'JJ',
#   'JJ',
#   'NNS',
#   '.'],
#  ['IN',
#   'PRP',
#   'VBP',
#   'VBG',
#   'JJ',
#   'JJ',
#   'NNS',
#   ',',
#   'DT',
#   'NN',
#   'NNS',
#   'VBP',
#   'RB',
#   'JJ',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'MD',
#   'RB',
#   'VB',
#   'JJ',
#   'JJ',
#   'JJ',
#   '.'],
#  ['NN',
#   'IN',
#   'NNP',
#   'NNP',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'NN',
#   'NN',
#   ',',
#   'NNP',
#   'CC',
#   'JJ',
#   'NN',
#   ',',
#   'NNS',
#   'NNS',
#   ',',
#   'NNS',
#   ',',
#   'NN',
#   'NNS',
#   ',',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   'CC',
#   'NNP',
#   'NNP',
#   'NN',
#   ',',
#   '_SP',
#   'CC',
#   'NNS',
#   '.'],
#  ['IN',
#   'JJ',
#   'JJ',
#   'NN',
#   'NN',
#   'NNS',
#   ',',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   'VBP',
#   'VBN',
#   'IN',
#   'NNS',
#   'IN',
#   'NNP',
#   'NNPS',
#   ',',
#   'NNP',
#   '.'],
#  ['DT',
#   'JJ',
#   'NNS',
#   'MD',
#   'VB',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NN',
#   'NN',
#   'CC',
#   'NN',
#   'NN',
#   '.'],
#  ['JJ',
#   'NN',
#   'NNP',
#   'DT',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'NNS',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   'NNS',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'IN',
#   'TO',
#   'CD',
#   'NNS',
#   'IN',
#   'NNS',
#   'IN',
#   'VBG',
#   '.'],
#  ['IN',
#   'DT',
#   'NN',
#   ',',
#   'PRP',
#   'MD',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'RB',
#   'CD',
#   'NN',
#   'IN',
#   'VBN',
#   'NN',
#   '.'],
#  ['IN',
#   'DT',
#   'NN',
#   'NN',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   '$',
#   'CD',
#   'DT',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'VBN',
#   'JJ',
#   'NN',
#   'NNS',
#   'IN',
#   '$',
#   'CD',
#   ',',
#   'VBN',
#   'DT',
#   'CD',
#   'NN',
#   'JJ',
#   'NN',
#   'NN',
#   ',',
#   'CC',
#   'RB',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'NNS',
#   'CC',
#   'NN',
#   'NNS',
#   '.'],
#  ['NN',
#   'IN',
#   'NNP',
#   'NNP',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'DT',
#   'NNP',
#   'IN',
#   'NNP',
#   ',',
#   'DT',
#   'NNP',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'NNS',
#   'IN',
#   'JJ',
#   'NNS',
#   ',',
#   'VBD',
#   'IN',
#   'IN',
#   'DT',
#   '``',
#   'NNS',
#   "''",
#   '.'],
#  ['DT',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'WDT',
#   'NNP',
#   'VBZ',
#   'JJ',
#   'CC',
#   'DT',
#   'NNS',
#   'VBP',
#   'VBN',
#   'IN',
#   'DT',
#   'NNS',
#   'VBP',
#   'VBN',
#   'VBN',
#   'CC',
#   'VBN',
#   'IN',
#   'NNP',
#   '.'],
#  ['DT',
#   'NN',
#   'MD',
#   'VB',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'VBG',
#   'CD',
#   'NN',
#   'VBN',
#   'CD',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['NNS',
#   'MD',
#   'VB',
#   'VBN',
#   'RB',
#   'DT',
#   'CD',
#   'NNS',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['DT',
#   'NNS',
#   'VBP',
#   'RB',
#   'VBN',
#   'IN',
#   'NN',
#   'CC',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['IN',
#   'JJ',
#   ',',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   ',',
#   'RB',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBN',
#   '.'],
#  ['IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBN',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'DT',
#   'NNS',
#   '.'],
#  ['DT',
#   'NN',
#   'NN',
#   'NN',
#   'VBZ',
#   'RB',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'VBN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   ',',
#   'WDT',
#   'PRP',
#   'VBP',
#   'MD',
#   'VB',
#   'RB',
#   'RBS',
#   '$',
#   'CD',
#   'CC',
#   'RB',
#   'RB',
#   'JJ',
#   'IN',
#   '$',
#   'CD',
#   '.'],
#  ['DT',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   '_SP',
#   '$',
#   'CD',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   '.'],
#  ['IN',
#   'VBN',
#   'IN',
#   'NN',
#   'NN',
#   'NNS',
#   'IN',
#   '$',
#   'CD',
#   ',',
#   "''",
#   'NNS',
#   "''",
#   'IN',
#   '$',
#   'CD',
#   'CC',
#   'DT',
#   'NN',
#   'VBD',
#   'IN',
#   '$',
#   'CD',
#   ',',
#   'JJ',
#   'VBN',
#   'NN',
#   'NN',
#   'VBZ',
#   '$',
#   'CD',
#   'WDT',
#   'VBZ',
#   '$',
#   'CD',
#   'TO',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   '.'],
#  ['DT',
#   'NN',
#   'RB',
#   'IN',
#   'VBG',
#   'DT',
#   'NN',
#   'NN',
#   'MD',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'VBD',
#   'PRP',
#   'VBD',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['RB',
#   ',',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'MD',
#   'VB',
#   '$',
#   'CD',
#   '.'],
#  ['RB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'MD',
#   'VB',
#   'DT',
#   'NNS',
#   ',',
#   'PRP',
#   'VBZ',
#   'JJ',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'NN',
#   'IN',
#   'NNS',
#   'VBN',
#   '.'],
#  ['DT',
#   'JJR',
#   'NNS',
#   'IN',
#   'NN',
#   'NNS',
#   'VBP',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['DT',
#   'NN',
#   'VBZ',
#   'VBG',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'WDT',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['VBG', 'NNS', 'IN', 'VBZ', '.'],
#  ['IN',
#   'DT',
#   'JJ',
#   'NN',
#   'VBD',
#   'CD',
#   'CD',
#   'NNS',
#   ',',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'MD',
#   'VB',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   '.'],
#  ['IN',
#   'DT',
#   ',',
#   'RB',
#   '$',
#   'CD',
#   'MD',
#   'VB',
#   'IN',
#   'NNS',
#   'CC',
#   '$',
#   'CD',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['DT',
#   'NNS',
#   'VBP',
#   'JJR',
#   'TO',
#   'VB',
#   'JJ',
#   'CD',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'NN',
#   'NNS',
#   ',',
#   'DT',
#   'NN',
#   'NN',
#   ',',
#   'NN',
#   'NN',
#   'NNS',
#   ',',
#   'VB',
#   'NN',
#   'CC',
#   'NN',
#   ',',
#   'CC',
#   'RB',
#   'RB',
#   ',',
#   'RB',
#   'RB',
#   'IN',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['DT',
#   'NN',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'MD',
#   'VB',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'VBN',
#   'JJ',
#   'NN',
#   'NN',
#   ',',
#   'WDT',
#   'PRP',
#   'MD',
#   'VB',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   '.'],
#  ['RB',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'VBN',
#   'NN',
#   'MD',
#   'VB',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   '.'],
#  ['DT',
#   'MD',
#   'VB',
#   'PRP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   '$',
#   'CD',
#   ',',
#   'JJ',
#   'NN',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'VBN',
#   'IN',
#   '$',
#   'CD',
#   '.'],
#  ['DT',
#   'VBD',
#   'RB',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'DT',
#   'RBR',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NNP',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   'MD',
#   'DT',
#   'VB',
#   'JJ',
#   'TO',
#   'VB',
#   'IN',
#   'PRP$',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['NNP', 'NNS', 'EX', 'VBP', 'CD', 'NNS', 'IN', '_SP', 'NN', 'NNS', '.'],
#  ['RB',
#   ',',
#   'VBZ',
#   'DT',
#   'JJ',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'NN',
#   'WDT',
#   'VBZ',
#   'VBN',
#   'RP',
#   'RB',
#   'IN',
#   'DT',
#   'JJ',
#   'JJ',
#   'JJ',
#   'NN',
#   '.'],
#  ['RB',
#   ',',
#   '_SP',
#   'VBZ',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'JJ',
#   'VBN',
#   'NN',
#   ',',
#   'CC',
#   'DT',
#   'NN',
#   'VBZ',
#   'IN',
#   'DT',
#   'NN',
#   'SYM',
#   'NNS',
#   'NN',
#   '.'],
#  ['JJ',
#   ',',
#   'VBZ',
#   'DT',
#   'JJ',
#   'JJ',
#   'VBN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
# ...
#   'VB',
#   'VB',
#   'WP',
#   'RB',
#   'PRP',
#   'VBZ',
#   '.'],
#  ['NN',
#   'NN',
#   'VBZ',
#   'VBG',
#   'TO',
#   'VB',
#   'RB',
#   '.',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'CC',
#   'NNP',
#   'NN',
#   'NN',
#   'VB',
#   'PRP',
#   'NN',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'VB',
#   'PRP$',
#   'JJ',
#   ',',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'NNP',
#   'NNP',
#   'IN',
#   'ADD'],
#  ['PRP',
#   'VBD',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   'NNP',
#   ',',
#   'CC',
#   'NNP',
#   'VBZ',
#   'DT',
#   'NN',
#   '_SP',
#   'IN',
#   'JJ',
#   'IN',
#   'NNP',
#   'NNP',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'TO',
#   'VB',
#   'RB',
#   ',',
#   'CC',
#   'PRP',
#   'VBP',
#   'VBG',
#   '_SP',
#   'TO',
#   'VB',
#   'DT',
#   'NNS',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['WP', 'VBP', 'PRP', 'VB', 'IN', 'VBG', 'NNP', 'CC', 'NN', 'NNS', '.'],
#  ['RB',
#   'MD',
#   'PRP',
#   'VB',
#   'IN',
#   'NNP',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'VBG',
#   'NN',
#   'CC',
#   'NN',
#   'NNS',
#   '.'],
#  ['UH', ',', 'NNP'],
#  ['PRP', 'VBD', 'DT', 'JJ', 'NN', 'CC', 'PRP', 'VBP', 'RB', 'VB', 'NN', '.'],
#  ['RB', ',', 'WP', 'VBP', 'PRP', 'VB', 'TO', '_SP', 'VB', 'IN', 'NN', '.'],
#  ['NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   'IN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'CD',
#   'CD',
#   'NN',
#   '_SP',
#   'VBN',
#   'RB',
#   ':',
#   'NNP',
#   'NNP',
#   'IN',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   '_SP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   '_SP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNPS',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'VB',
#   '_SP',
#   'NN',
#   ':',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'DT',
#   'VBZ',
#   'DT',
#   'NN',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['EX', 'MD', 'VB', 'DT', 'NNP', 'NNP', 'NNP', 'CD', ',', 'CD', '.'],
#  ['DT',
#   'NN',
#   'VBZ',
#   'DT',
#   'DT',
#   'NNP',
#   'NNP',
#   'CC',
#   'MD',
#   'VB',
#   'VBN',
#   'DT',
#   'JJ',
#   '_SP',
#   'NNP',
#   '.'],
#  ['NN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'CD',
#   ',',
#   'CD',
#   '_SP',
#   'NNP',
#   ':',
#   '_SP',
#   'CD',
#   'NN',
#   'HYPH',
#   'CD',
#   'NN',
#   '_SP',
#   'NNP',
#   ':',
#   'CD',
#   '_SP',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NNS',
#   'CC',
#   'NNS',
#   ',',
#   'UH',
#   'VB',
#   'JJ',
#   'TO',
#   'VB',
#   'PRP',
#   '-LRB-',
#   'CD',
#   'SYM',
#   'CD',
#   '-RRB-',
#   '_SP',
#   'CC',
#   'NNP',
#   '-LRB-',
#   'CD',
#   'SYM',
#   'CD',
#   '-RRB-',
#   '.'],
#  ['NNS', ',', 'NNP', 'CD', 'SYM', 'CD'],
#  ['NNP',
#   ',',
#   'DT',
#   'VBZ',
#   'DT',
#   'NN',
#   'PRP',
#   'VBP',
#   ':',
#   'ADD',
#   'HYPH',
#   'NN',
#   'SYM',
#   'NN',
#   'SYM',
#   'NNP',
#   'MD',
#   'PRP',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['NNP',
#   ',',
#   '_SP',
#   'VBD',
#   'PRP',
#   'VB',
#   'DT',
#   'JJR',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP', 'VBZ', '_SP', 'VBG', 'PRP', 'IN', 'JJ', 'NNS', 'CC', 'NN', '.'],
#  ['WP', 'VBP', 'PRP', 'VB', 'TO', 'VB', '.'],
#  ['NNP'],
#  ['NNP', 'UH', 'VB', 'NNP', 'DT', 'VBN', 'JJ', 'NNS', 'NNS', ',', 'NNP'],
#  ['_SP',
#   'NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'CD',
#   'CD',
#   'NN',
#   'TO',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'CD',
#   '_SP',
#   'NN',
#   ':',
#   '_SP',
#   'VB',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   ',',
#   'PRP',
#   'VBD',
#   'DT',
#   'NN',
#   '.'],
#  ['IN',
#   'DT',
#   'NN',
#   'NN',
#   ',',
#   'PRP',
#   'VBP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'VBP',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'PRP',
#   'VBD',
#   'IN',
#   'PRP',
#   'DT',
#   'JJ',
#   'NNS',
#   'RB',
#   ',',
#   'WDT',
#   'PRP',
#   'VB',
#   'VBN',
#   'NFP',
#   '_SP',
#   'MD',
#   'PRP',
#   'VB',
#   '.'],
#  ['UH',
#   ',',
#   'NNP',
#   'NNP',
#   '_SP',
#   'NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   'CD',
#   'CD',
#   'CD',
#   'NN',
#   'TO',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   '_SP',
#   'NN',
#   ':',
#   '_SP',
#   'VB',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   ',',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'NN',
#   'RB',
#   'IN',
#   'IN',
#   'PRP',
#   'VBZ',
#   'DT',
#   'IN',
#   'DT',
#   '``',
#   'JJ',
#   'JJ',
#   'SYM',
#   'JJ',
#   'NNS',
#   "''",
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['NNP',
#   'VBZ',
#   'TO',
#   'VB',
#   'DT',
#   'VBN',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'POS',
#   '``',
#   'NNP',
#   'NNP',
#   'NNP',
#   "''",
#   'IN',
#   'NNP',
#   '.'],
#  ['PRP',
#   'RB',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'IN',
#   'NNP',
#   '.'],
#  ['MD', 'PRP', 'VB', 'DT', 'CD', 'NNS', 'IN', 'NNP', 'NN', '.'],
#  ['NN',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'JJ',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'JJ',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'NNP',
#   '_SP',
#   'JJ',
#   '_SP',
#   'NNP'],
#  ['PRP', 'VBD', 'TO', 'VB', 'DT', 'NN', 'CC', 'PRP', 'VBD', 'RB', 'VB'],
#  ['NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   'NFP',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'IN',
#   ':',
#   '_SP',
#   'NNP',
#   'NNP',
#   '_SP',
#   'CD',
#   'CD',
#   'NN',
#   '_SP',
#   'TO',
#   ':',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'VB',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   '_SP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   '_SP',
#   'RB',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   ',',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'CD',
#   '_SP',
#   'NN',
#   ':',
#   'NN',
#   'NN',
#   'UH',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'NNP',
#   'CD',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'CD',
#   'TO',
#   '_SP',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['RB',
#   'IN',
#   'PRP',
#   'VBP',
#   'VBN',
#   'JJ',
#   'NNS',
#   '_SP',
#   'VBG',
#   'NN',
#   'NNS',
#   'IN',
#   'JJ',
#   'NNS',
#   ',',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   '_SP',
#   'DT',
#   'NNS',
#   'PRP',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   'DT',
#   'NN',
#   'VBZ',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBN',
#   'NNP',
#   'NNP',
#   '_SP',
#   '-LRB-',
#   'NN',
#   '-RRB-',
#   ',',
#   'NNP',
#   'NNP',
#   'CC',
#   'NNP',
#   'NNP',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'TO',
#   'VB',
#   'IN',
#   'PRP',
#   '_SP',
#   'MD',
#   'VB',
#   'JJ',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NNS',
#   '.'],
#  ['DT',
#   'NN',
#   'IN',
#   'DT',
#   '_SP',
#   'NN',
#   'VBZ',
#   'TO',
#   'VB',
#   'DT',
#   'NNS',
#   'RP',
#   'IN',
#   'DT',
#   'JJ',
#   'CC',
#   'VB',
#   'JJ',
#   'NN',
#   'VBZ',
#   '_SP',
#   'JJ',
#   'IN',
#   'VBG',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'NN',
#   ',',
#   'CC',
#   'TO',
#   'VB',
#   'JJ',
#   'DT',
#   '_SP',
#   'WP',
#   'VBP',
#   'VBG',
#   'DT',
#   'NNS',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   'POS',
#   'NNS',
#   '.'],
#  ['IN',
#   'PRP',
#   'VBP',
#   '_SP',
#   'VBN',
#   'DT',
#   'JJ',
#   'NNS',
#   ',',
#   'PRP',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'TO',
#   '_SP',
#   'VB',
#   'PRP',
#   '.'],
#  ['UH', 'VB', 'PRP', 'VB', 'IN', 'PRP', 'VBP', 'JJ', 'TO', 'VB', '.'],
#  ['NNP',
#   ',',
#   '_SP',
#   'PRP',
#   'VBP',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'CC',
#   'NNP',
#   'NNP',
#   'MD',
#   'VB',
#   '.'],
#  ['PRP',
#   'VBZ',
#   'VBN',
#   '_SP',
#   'VBG',
#   'DT',
#   'NNP',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   '.'],
#  ['NNP'],
#  ['NNP',
#   ',',
#   '_SP',
#   'RB',
#   'IN',
#   '$',
#   'CD',
#   'VBZ',
#   'VBN',
#   'CC',
#   'PRP',
#   'VBP',
#   'VBN',
#   'RP',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   ',',
#   'PRP',
#   '_SP',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'NNS',
#   'CC',
#   'NN',
#   '.'],
#  ['RB',
#   ',',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'VBG',
#   'NNS',
#   ':',
#   '_SP',
#   'CD',
#   '.'],
#  ['DT', 'NN', 'IN', 'PRP$', 'VBN', '-LRB-', 'CC', 'NN', '-RRB-', 'NNS', '.'],
#  ['LS', '.'],
#  ['JJ',
#   'NNS',
#   'IN',
#   'PRP',
#   'CC',
#   'NNP',
#   'VBD',
#   'IN',
#   'PRP',
#   'RB',
#   '_SP',
#   'CD',
#   '.'],
#  ['NNS',
#   'MD',
#   'VB',
#   'VBN',
#   'DT',
#   'NNP',
#   'IN',
#   'PRP',
#   'IN',
#   'DT',
#   'NNP',
#   'NNP',
#   '_SP',
#   'CD',
#   '.'],
#  ['DT',
#   'JJR',
#   'NNS',
#   'IN',
#   'NN',
#   'CC',
#   'NN',
#   'IN',
#   'VBZ',
#   'JJ',
#   'IN',
#   'JJ',
#   '_SP',
#   'NNS',
#   '.'],
#  ['VBG',
#   'RP',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'PRP',
#   'VBP',
#   'VBN',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'DT',
#   '_SP',
#   'DT',
#   'NNS',
#   'IN',
#   'NNP',
#   'CD',
#   '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   ',',
#   'VB',
#   'IN',
#   'DT',
#   '``',
#   'NNP',
#   "''",
#   'NN',
#   'CC',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   '_SP',
#   'VBN',
#   'NNS',
#   '.'],
#  ['PRP', 'VBP', 'NNS', 'IN', 'DT', 'NNS', '.'],
#  ['UH', 'VB', 'NNS', 'IN', 'PRP', 'MD', 'VB', '.'],
#  ['NNP'],
#  ['UH',
#   ',',
#   '_SP',
#   'WRB',
#   'JJ',
#   'NNS',
#   'VBP',
#   'PRP',
#   'VB',
#   'NNP',
#   'VBZ',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   '.'],
#  ['UH',
#   'VB',
#   'NNP',
#   'NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NN',
#   ':',
#   '_SP',
#   'IN',
#   ':',
#   '_SP',
#   'NNP',
#   'DT',
#   'NNP',
#   '_SP',
#   'CD',
#   'CD',
#   'NN',
#   '_SP',
#   'TO',
#   ':',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'NN',
#   ':',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   '_SP',
#   'NN',
#   ':',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'JJ',
#   ':',
#   'VB',
#   'NN',
#   'IN',
#   'NN',
#   'UH',
#   'VB',
#   'NNP',
#   'CC',
#   'NNP',
#   'NNP',
#   'VB',
#   '.'],
#  ['NNS', '.'],
#  ['NNP',
#   'NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NNP',
#   ':',
#   '_SP',
#   'ADD',
#   'IN',
#   'CD',
#   'CD',
#   'NN',
#   'TO',
#   ':',
#   'NNP',
#   'NNP',
#   ':',
#   '_SP',
#   'NN',
#   ':',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'JJ',
#   ':',
#   'VB',
#   'NN',
#   'IN',
#   'NN',
#   '_SP',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'VBG',
#   'PRP$',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['UH',
#   'VB',
#   '_SP',
#   'ADD',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NN',
#   'SYM',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'NNP',
#   'IN',
#   '_SP',
#   'CD',
#   'HYPH',
#   'CD',
#   'HYPH',
#   'CD',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NNS',
#   '.'],
#  ['NNP',
#   'NNP',
#   '_SP',
#   ':',
#   'CD',
#   'NN',
#   'NN',
#   'NN',
#   ':',
#   'CD',
#   'CD',
#   'NN',
#   'NNP',
#   'IN',
#   '_SP',
#   ':',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   ':',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'XX',
#   'CC',
#   'SYM',
#   'CD',
#   '_SP',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   ':',
#   'NNS'],
#  ['UH',
#   ',',
#   '_SP',
#   'PRP',
#   'VBP',
#   'VBG',
#   'DT',
#   'NN',
#   'NNS',
#   'IN',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   '.'],
#  ['UH', 'VB', '_SP', 'NN', 'IN', 'DT', '.'],
#  ['NNP',
#   '_SP',
#   'NFP',
#   'VBN',
#   'IN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'IN',
#   'CD',
#   '_SP',
#   'CD',
#   'NNP',
#   ':',
#   '_SP',
#   'ADD',
#   'IN',
#   'CD',
#   'CD',
#   'NN',
#   'TO',
#   ':',
#   'NNP',
#   'NNP',
#   ':',
#   '_SP',
#   'NN',
#   ':',
#   'NNP',
#   'VBN',
#   ':',
#   'NN',
#   'NN',
#   'IN',
#   'ADD',
#   '_SP',
#   'UH',
#   'VB',
#   'CC',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBN',
#   'DT',
#   'NN',
#   'IN',
#   '_SP',
#   'DT',
#   'NN',
#   'VBD',
#   'PRP',
#   'IN',
#   'PRP$',
#   'NNP',
#   '.'],
#  ['UH',
#   'VB',
#   '_SP',
#   'ADD',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NNP',
#   'SYM',
#   'NN',
#   'TO',
#   'VB',
#   'UH',
#   '_SP',
#   'NNP',
#   'NNP',
#   '_SP',
#   ':',
#   'CD',
#   'NN',
#   'NN',
#   'NN',
#   ':',
#   'CD',
#   'CD',
#   'VBP',
#   'VBN',
#   'IN',
#   '_SP',
#   ':',
#   'ADD',
#   'NNP',
#   'NNP',
#   '_SP',
#   ':',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   'NNP',
#   '_SP',
#   ':',
#   'NNS'],
#  ...]

# %% [markdown]
# ## Generalization
# <br>
# some business action terms added along with action phrases

# %%
# pattern matching

def action_item_match(sent):
    sent = sent.lower()
    a=0

    action_pattern = ["let's", "let us","let me know","let us know", "we have to", "we have", 
                      "i have to", "please", "we need", "we need to",
                      "can you", "request", "define", "formulate",
                      "drill down", "call", "check","schedule", "could you", "would you",
                      "you should", "we expect", "you have", "we've had",
                      "i expect"]

    for ptrn in action_pattern:
        if ptrn in sent:
            a=1

    return a

# %% [markdown]
# ### Rules from the observation.
#
# - Sentence starting with 'Modals' like *could,will...*
# <br>(MD)
# - Sentence starting with 'Verb in base form' like *call,run...*
# <br>(VB)
# - Sentence has 'adverb'(RB) immediately followed by 'base verb'(VB) *example: big task*
# - sentence has 'interjection'(UH) and a 'base verb' or verb in present tense follows example: *ummm you may call*
# - sentence has personal nouns like I,he... followed by a base verb or verb in present tense.
# - sentence has 'noun' followed by 'base verb' or modal like *Ravi could*
# - modal followed by adverb personal pronoun like *the task you should do*
# - sentence has determiner and base verb follows
# <br>
# <br>
#
# refer:https://pythonprogramming.net/chunking-nltk-tutorial/?completed=/part-of-speech-tagging-nltk-tutorial/
#
# <br>
#
# https://linguistics.stackexchange.com/questions/11083/detecting-actions-within-text
# <br>

# %%
#The above rules as regex

#(RB VB)     # take printouts of the report

#(UH*VB) # hmm collect the file 

#(UH*VBP)

#(PRP VB|VBP) 

#(NN.*VB|MD) 

#(DT*VB)

# %%
def action_item_rule(docs,tags1):
    
    a=0

    # sentence starts with base verb or modals like 'could you send me the file by eod'
    if tags1[0] == "VB" or tags1[0] == "MD":
        a = 1
    else:
        tags1 = ' '.join(tags1)
        if re.search("DT.*VB", tags1):
            a = 1
        elif re.search("RB VB", tags1):
            a = 1
        elif re.search("UH.*VB", tags1):
            a = 1
        elif re.search("UH.*VBP", tags1):
            a = 1
        elif re.search("PRP VB|VBP", tags1):
            a = 1
        elif re.search("NN.*VB|MD", tags1):
            a = 1

        # check if sentence contains the word 'please','define' etc
        else:
            a = action_item_match(docs.text)
        
    return a

# %% [markdown]
# ## Classifying the sentences.

# %%
label = []

for i in range(NUMBER_OF_SENTENCES):

    l = action_item_rule(lst_doc[i], lst_tags[i])
    label.append(l)

# %%
import copy
data_labeled_df = copy.deepcopy(sentences_df.head(NUMBER_OF_SENTENCES))

# %%
data_labeled_df['label'] = label

# %%
data_labeled_df.to_csv("rule_gen_label.csv", index = False)

# %%
data_labeled_df
# Out:
#                                                                                                                                                                                                   sentence  \
# 0                                                                                                                                                                                     Here is our forecast
# 1                                                                                                                                      Traveling to have a business meeting takes the fun out of the trip.
# 2                                                                                                                                                        Especially if you have to prepare a presentation.
# 3                                                                                           I would suggest holding the business plan meetings here then take a trip without any formal business meetings.
# 4                                                                                                            I would even try and get some honest opinions on whether a trip is even desired or necessary.
# ...                                                                                                                                                                                                    ...
# 49995  For power sellers in the West, the current price caps often require utilities to sell their excess power at a loss, Enron, Sierra Pacific and other marketers said in statements to the commission.
# 49996                                                                   They said the price they sometimes pay for power is higher than the cost of supply from the most-expensive producer in California.
# 49997                                                                          ``The determination of the proxy price should not be limited to California generators,'' Enron said in a government filing.
# 49998                                                                                                                     It should be ``determined by the least-efficient generator in the entire West.''
# 49999                                                                                         Power marketers also should be allowed to recover ``justifiable costs above the proxy prices,'' Enron wrote.
#
#        label
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 49995      0
# 49996      0
# 49997      0
# 49998      0
# 49999      0
#
# [50000 rows x 2 columns]

# %% [markdown]
# ## test on pre tagged data

# %%
test_ = "actions.csv"
actions_df = pd.read_csv(test_, names =['action_sentence'])
actions_df
# Out:
#                                         action_sentence
# 0     Activate all who work with Transmission or hav...
# 1     Add more to your score by stopping in and pick...
# 2     Add O'neal Winfee and George Smith to the atte...
# 3     Additionally, send me the payment schedule for...
# 4     Adjust our purchase amount from each party bas...
# ...                                                 ...
# 1245  Write me note about what is going on and what ...
# 1246  Write verification plans specifications and do...
# 1247       you have to expand on the maintenance tools.
# 1248  You have to resolve Enron's ongoing concerns a...
# 1249  Your task is to deliver them to Janet for exec...
#
# [1250 rows x 1 columns]

# %%
test_NUMBER_OF_SENTENCES= 1250
        
test_doc, test_tags = gen_tags(actions_df['action_sentence'][0:test_NUMBER_OF_SENTENCES])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1250/1250 [00:06<00:00, 201.01it/s]

# %%
test_label = []

for j in range(test_NUMBER_OF_SENTENCES):

    l_test = action_item_rule(test_doc[j], test_tags[j])
    test_label.append(l_test)

# %%
#accuracy on pretagged data
test_label.count(1)/1250
# Out:
# 0.9952
